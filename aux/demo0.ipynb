# %% [markdown]
# # demo

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
plt.style.use("ggplot")

# %%
import numpy as np

# %%
import quantiphy

# %%
L = -12
L = quantiphy.Quantity(str(L) +'Hz')
quantiphy.Quantity('1420.405751786 MHz')
# Out:
# Quantity('1.420405751786 GHz')

# %%
PI = 3.141592653589793

# %%
# demo skrf
import skrf
skrf.plotting.smith(chart_type='zy')

# %%
skrf.plotting.plot_smith(s=[.5,.52, .2+.4j, .12-.12j])
